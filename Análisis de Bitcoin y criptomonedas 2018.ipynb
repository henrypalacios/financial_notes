# %% [markdown]
# # Capitalización de Bitcoin al cierre 2018 y principales criptomonedas

# %% [markdown]
# ### Importando Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
# Setting plot more size for later
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Datos de las principales 100 coins/tokens, API coinmarketcap

# %%
top100 = pd.read_json("https://api.coinmarketcap.com/v1/ticker/?limit=0")
top100.head(20)
# Out:
#     24h_volume_usd  available_supply                id  last_updated  \
# 0     4.683608e+09          17455525           bitcoin    1546287622
# 1     5.065213e+08       40794121066            ripple    1546287605
# 2     2.390000e+09         104120997          ethereum    1546287624
# 3     1.809554e+08          17541200      bitcoin-cash    1546287614
# 4     7.256370e+08         906245118               eos    1546287614
# 5     9.881807e+07       19160776295           stellar    1546287607
# 6     3.515917e+09        1858694256            tether    1546287610
# 7     3.720860e+08          59814577          litecoin    1546287605
# 8     5.316294e+07          17540061        bitcoin-sv    1546287641
# 9     6.650138e+07       66634505614              tron    1546287618
# 10    1.977191e+07       25927070538           cardano    1546287618
# 11    1.069131e+07        2779530283              iota    1546287614
# 12    3.605218e+07         130799308      binance-coin    1546287615
# ...

# %% [markdown]
# ### API anterior sera deprecada, se persisten los datos para el análisis

# %%
current.to_csv('dataset_cmc_31122018.csv')

# %%
df = pd.read_csv('dataset_cmc_31122018.csv')

market_cap_raw = pd.DataFrame(data=dec31, columns=['id', 'market_cap_usd'])

market_cap_raw.count()
# Out:
# id                100
# market_cap_usd    100
# dtype: int64

# %% [markdown]
# # Total Market Capitalization Dec, 31 2018

# %%
total_cap = market_cap.market_cap_usd.sum()

print("${:,} USD".format(total_cap))
# Out:
# $123,355,816,748 USD

# %%
# Selecting the first 20 rows
top20 = market_cap[:20]

# Set id as Index
top20.set_index('id', inplace=True)

print(top20.head())
# Out:
#               market_cap_usd
# id
# bitcoin          66345952337
# ripple           14669291114
# ethereum         14278377716
# bitcoin-cash      2790403373
# eos               2364214118

# %% [markdown]
# ### Porcentaje de la capitalización de las 20 principales (ordenadas por market_cap)

# %%
# Calculating market_cap_perc
top20 = top20.assign(market_cap_perc = lambda x: (x.market_cap_usd/market_cap_raw.market_cap_usd.sum()) * 100)

# %%
# Plotting the barplot with the title defined above 
ax = cap10.plot.bar(y='market_cap_perc', label='Percentage of Market Capitalization')


# Annotating the y axis with the label defined above
plt.ylabel(TOP_CAP_YLABEL)
plt.xlabel('name of coin/token')
plt.title(TOP_CAP_TITLE)
plt.show()

# %% [markdown]
# > **Bitcoin** para el cierro 2018 representa mas el **52%** de la capitalización del espacio de Criptomonedas.
# > siendo **ripple** y **ethereum** las que le siguen con tan solo un poco mas del **10%**
